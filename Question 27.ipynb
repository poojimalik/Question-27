# %%
list1 = [12,34,56,78,90]
list2 = [34,56,89,90]
merged_list = []
i = j = 0
while i < len(list1) and j < len(list2)
    if list1[i] <= list2[j]:
        merged_list.append(list1[i])
        i = i + 1
    else
        merged_list.append(list2[j])
        j = j + 1
    print(merged_list)

# add remaining elements from list2 or list1
while i < len(list1):
    merged_list.append(list1[i])
    i = i + 1
while j < len(list2):
    merged_list.append(list2[j])
    j = j + 1
    print(merged_list)

# %%
def merge_sorted_list(list1, list2: list) -> list:
    
    if not isinstanc(list1,list) or not isinstance(list2,list):
        raise TypeError("Both input must be lists")
        
    for item in list1 + list2:
        if not isinstance(item,(int,float)):
            raise TypeError("Lists must contain only numbers")
    
    
    merged_list = []
    i = j = 0
    while i < len(list1) and j < len(list2)
      if list1[i] <= list2[j]:
        merged_list.append(list1[i])
        i = i + 1
    else:
        merged_list.append(list2[j])
        j = j + 1
    print(merged_list)

# add remaining elements from list2 or list1
    while i < len(list1):
    merged_list.append(list1[i])
    i = i + 1
   while j < len(list2):
    merged_list.append(list2[j])
    j = j + 1
    print(merged_list)
if__name__=="__main__":
    list1 = [4,34,56,78,90,7000]
    list2 = [1,1,1,1,1,1,1,1,1,]
    try: 
        print(merge_sorted_list(list1,list2))
    except Exception as e:
        print(e)
